# %%
import sys
import time
from riotwatcher import RiotWatcher, NORTH_AMERICA, LoLException
import cPickle

def save_obj(obj, filename ):
    with open(filename, 'wb') as f:
        cPickle.dump(obj, f, cPickle.HIGHEST_PROTOCOL)

def load_obj(filename):
    with open(filename, 'rb') as f:
        return cPickle.load(f)

def secondsToStr(t):
    rediv = lambda ll,b : list(divmod(ll[0],b)) + ll[1:]
    return "%d:%02d:%02d.%03d" % tuple(reduce(rediv,[[t*1000,],1000,60,60]))

key = 'd8eb3b3a-6401-42af-bb07-a021fd8d9545'
w = RiotWatcher(key)

def get_participants_for_further_pulls(match):
    """ This function takes a riot api 'match' and returns only selected
        participant information. You may add to the returned information
        if you want.
        The return value is a list of dictionaries, one for each
        participant in the match. """
    participants = [ {} for i in range(len(match['participants'])) ]
    for i,p in enumerate(match['participants']):
        participants[i]['highestAchievedSeasonTier'] = p['highestAchievedSeasonTier']
        participants[i]['summonerId'] = match['participantIdentities'][p['participantId']-1]['player']['summonerId']
    return participants

def get_match_information_to_save(match):
    """ This function takes a riot api 'match' and parses
        through it to save only the information you want. You can
        choose to save everything, or only specific things.
        The return value is a dictionary containing only the
        information you want to save for the match. """
    # Uncomment the following line to save all the data
    #return match
    data = {}
    # The below code is an example of specific data to save
    data['matchId'] = match['matchId'] # You MUST at least include this field!
    data['matchMode'] = match['matchMode']
    data['matchCreation'] = match['matchCreation']
    data['matchVersion'] = match['matchVersion']
    data['season'] = match['season'] #let's see if this little edit works...
    data['queueType'] = match['queueType']
    data['mapId'] = match['mapId']
    data['winningChamps'] = []
    data['losingChamps'] = []
    for p in match['participants']:
        if(p['stats']['winner']):
            data['winningChamps'].append(p['championId'])
        else:
            data['losingChamps'].append(p['championId'])
    return data

def parse_match_history(match_history):
    """ This function takes a summoner's match history and
        returns the matchIds from that match history along
        with the full list of matches. There is no reason
        to modify this function. """
    matchIds = [ match['matchId'] for match in match_history['matches'] ]
    return matchIds, match_history['matches']

def pull_this_match(match):
    """ This function takes a match from the *match history* request
        and returns True or False based on whether you want to 
        pull the match. If you want to pull every match, regardless
        of map type, etc. then just return True. """
    # This line parses the match's patch version into a usable format
    # For example, if the patch is 4.20.0.319 then
    # version == [4, 20, 0, 319]
    # Elliot: I am going to grab everything in SEASON2016 only
    if match['season'] == 'SEASON2016':
#     ranked_match_types = ['RANKED_SOLO_5x5']
#     version = [int(x) for x in match['matchVersion'].split('.')]
#     if(match['mapId'] == 11
#          and match['queueType'] == 'RANKED_SOLO_5x5'):
#          and version[0] == 5 and version[1] >= 3):
        return True
    else:
        return False

def save_this_match(match):
    """ This function takes a match from the *match* request
        and returns True or False based on whether you want to
        save the match data. If you want to save every match
        then just return True. """
    # I will only save the match if there is a diamond player in it.
    save = False
    for p in match['participants']:
        if(p['highestAchievedSeasonTier'] == 'DIAMOND'):
            save = True
            break
    return save

def pull_this_participant(p):
    """ This function takes a participant from a match and
        returns True or False based on whether you want to 
        pull this summoner's data. """
    # I only want to pull the summoner if it is diamond tier.
    # I can only get highestAchievedSeasonTier  so I'll use that.
    if(p['highestAchievedSeasonTier'] == 'DIAMOND'):
        return True
    else:
        return False



def main():
    # BEFORE YOU RUN THIS FILE, MAKE A BACKUP OF ALL THE DATA IT'S GOING TO USE.
    # This data will be in one of the files opened below, so make copies
    # of all those files in case something goes wrong.

    try:
        if(sys.argv[1] == 'reset'):
            print("WARNING: RESETTING ALL DATA IN 2 SECONDS!")
            print("You must manually re-copy your backed up version of unpulled_summoners.txt into that file.")
            print("The actual game data is not deleted, but it will be overwritten.")
            time.sleep(2)
            open('pulled_summoners.txt','w')
            open('pulled_matchIds.txt','w')
            open('paramfile.in','w').write('0')
    except:
        pass
    
    try:
        pulled_matchIds = open('pulled_matchIds.txt','r').readlines()
        pulled_matchIds = [int(x) for x in pulled_matchIds]
    except IOError:
        pulled_matchIds = []
    pulled_matchIds_file =  open('pulled_matchIds.txt','a')

    try:
        pulled_summoners = open('pulled_summoners.txt','r').readlines()
        pulled_summoners = [int(x) for x in pulled_summoners]
    except IOError:
        pulled_summoners = []
    pulled_summoners_file = open('pulled_summoners.txt','a')

    try:
        unpulled_summoners = open('unpulled_summoners.txt','r').readlines()
        unpulled_summoners = [int(x) for x in unpulled_summoners]
    except IOError:
        unpulled_summoners = []

    match_data_to_save = []
    these_pulled_summoners = []
    these_pulled_matches = []
    t_start = time.time()
    num_matches = 0.0
    num_pulled_summoners = 0.0
    pulled_matches = 0.0
    matched_you_actually_wanted = 0.0
    try:
        step = int(open('paramfile.in','r').readline())
    except IOError:
        step = 0
    while(True):
        # Start by getting a new summoner to pull matchID information for
        # If there is a summoner in unpulled_summoners, use that
        # If the unpulled_summoners list is empty, start at the beginning
        # of the summoners we have already pulled (their game data is
        # hopefully out of date by now).
        try:
            new_summoner = unpulled_summoners.pop()
        except IndexError:
            new_summoner = pulled_summoners.pop(0)
            print("Ran out of unpulled summoners, redoing a pulled summoner now. {0}".format(new_summoner))
        print("Getting match history from summoner: {0}".format(new_summoner))
        try:
            match_history = w.get_match_history(new_summoner,season_list='SEASON2016')
        except Exception,e:
            print("An ERROR occurred when pulling match history data for summonerId {0}! {1}".format(new_summoner,e))
            #print traceback.format_exc()
            continue
        try:
            matchIds, matches = parse_match_history(match_history)
        except KeyError,e:
            print("Some field you tried to access did not exist in the pulled summoner data: {0}".format(e))
            continue
        pulled_summoners.append(new_summoner)
        these_pulled_summoners.append(new_summoner)

        # Now we will pull the matches that were in this summoner's match history
        # if we decide it has data we want (see function pull_this_match)
        # If all the information you want is in the match history pull, you
        # can delete the pull request and modify the functions specified
        # however you want.
        for i,match in enumerate(matches):
            if(match['matchId'] not in pulled_matchIds and pull_this_match(match)):
                # Pull match
                print("  Getting match data for matchId {0}...".format(match['matchId']))
                try:
                    match_data = w.get_match(match['matchId'],include_timeline=False)
                except LoLException:
                    pulled_matchIds.append(match['matchId'])
                    these_pulled_matches.append(match['matchId'])
                    continue
                pulled_matches += 1.0
                # Append the matchId to the pulled matches list
                pulled_matchIds.append(match_data['matchId'])
                these_pulled_matches.append(match_data['matchId'])
                # Get participants in match
                participants = get_participants_for_further_pulls(match_data)
                # Add participants to unpulled summoners if necessary
                for p in participants:
                    # Unforunately, this if statement can take a while if there is enough
                    # data, but it's worth it not to pull data you already have.
                    if(pull_this_participant(p) and p['summonerId'] not in pulled_summoners and p['summonerId'] not in unpulled_summoners):
                        unpulled_summoners.append(p['summonerId'])
                # If the match information is what you want (see the save_this_match function)
                # then append the data you want to save to the list that we will save.
                if(save_this_match(match_data)):
                    # Save only specific information from each match (see the function)
                    match_data = get_match_information_to_save(match_data)
                    match_data_to_save.append(match_data)
                    num_matches += 1
                    matched_you_actually_wanted += 1
        # When we get 100+ games worth of new data, save them all to a new file.
        # This is nice because it prevents your files from becoming enormous,
        # and if you lose one you don't lose them all. It creates a bit more code
        # but I think it's worth it.
        # Note that there will not necessarily be exactly 100 games per file.
        if(num_matches >= 100):
            print("SAVING {0} MATCHES!".format(num_matches))
            # This saves the data as a cPickle. See Python's documentation for more info.
            save_obj(match_data_to_save,'Game Data/game_data_{0}.pkl'.format(step))
            match_data_to_save = []
            num_matches = 0
            for mid in these_pulled_matches:
                pulled_matchIds_file.write("{0}\n".format(mid))
            these_pulled_matches = []
            # Save (append) the summonerIds we pulled to file
            for summoner in these_pulled_summoners:
                pulled_summoners_file.write("{0}\n".format(summoner))
            these_pulled_summoners = []
            # Save (overwrite) unpulled_summoners to file
            unpulled_summoners_file = open('unpulled_summoners.txt','w')
            for summoner in unpulled_summoners:
                unpulled_summoners_file.write("{0}\n".format(summoner))
            unpulled_summoners_file.close()
            # Increment step
            step += 1
            # Update the parameter file to the step number so that
            # if we restart this python program all our all data
            # does not get erased. Right now the only line in that file
            # is the step number.
            open('paramfile.in','w').write(str(step))
        num_pulled_summoners += 1.0
        print("  Approximate number of successfully pulled matches: {0}".format(pulled_matches))
        print("  Average time per (successful) match request: {0}".format((time.time()-t_start)/matched_you_actually_wanted))
        print("Number of successfully pulled summoners: {0}".format(num_pulled_summoners))
        print("Average time per (successfully pulled) summoner: {0}".format((time.time()-t_start)/num_pulled_summoners))





if __name__ == '__main__':
    main()
# Out:
# Getting match history from summoner: 19944647
# An ERROR occurred when pulling match history data for summonerId 19944647! Too many requests
# Getting match history from summoner: 30542425
#   Getting match data for matchId 2294483258...
#   Getting match data for matchId 2294388494...
#   Getting match data for matchId 2294390096...
#   Getting match data for matchId 2293897255...
#   Getting match data for matchId 2293777086...
#   Getting match data for matchId 2293772352...
#   Getting match data for matchId 2293717337...
#   Getting match data for matchId 2293711900...
#   Getting match data for matchId 2293329207...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2293365876...
#   Getting match data for matchId 2293352691...
#   Getting match data for matchId 2293114273...
#   Getting match data for matchId 2293019010...
#   Getting match data for matchId 2293005415...
#   Getting match data for matchId 2292463959...
#   Getting match data for matchId 2291670857...
#   Getting match data for matchId 2291519114...
#   Getting match data for matchId 2290684994...
#   Getting match data for matchId 2290638311...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2290616383...
#   Getting match data for matchId 2290611700...
#   Getting match data for matchId 2289296952...
#   Getting match data for matchId 2287580685...
#   Getting match data for matchId 2287507345...
#   Getting match data for matchId 2286558214...
#   Getting match data for matchId 2286553300...
#   Getting match data for matchId 2286091339...
#   Getting match data for matchId 2286029273...
#   Getting match data for matchId 2285362015...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2284898000...
#   Getting match data for matchId 2284902656...
#   Getting match data for matchId 2284849019...
#   Getting match data for matchId 2284834825...
#   Getting match data for matchId 2284362681...
#   Getting match data for matchId 2284306406...
#   Getting match data for matchId 2284195839...
#   Getting match data for matchId 2284160865...
#   Getting match data for matchId 2283644466...
#   Getting match data for matchId 2283569530...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2283414971...
#   Getting match data for matchId 2283359354...
#   Getting match data for matchId 2282282760...
#   Getting match data for matchId 2282174773...
#   Getting match data for matchId 2281732364...
#   Getting match data for matchId 2280133852...
#   Getting match data for matchId 2279989278...
#   Getting match data for matchId 2272868749...
#   Getting match data for matchId 2262352723...
#   Getting match data for matchId 2243766542...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2243208095...
#   Getting match data for matchId 2242096645...
#   Getting match data for matchId 2242093736...
#   Getting match data for matchId 2242091414...
#   Getting match data for matchId 2242018456...
#   Getting match data for matchId 2239141260...
#   Getting match data for matchId 2238421170...
#   Getting match data for matchId 2237507286...
#   Getting match data for matchId 2237524390...
#   Getting match data for matchId 2237511338...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2237316068...
#   Getting match data for matchId 2236818781...
#   Getting match data for matchId 2236836492...
#   Getting match data for matchId 2236814026...
#   Getting match data for matchId 2236724760...
#   Getting match data for matchId 2235925499...
#   Getting match data for matchId 2235913852...
#   Getting match data for matchId 2235796770...
#   Getting match data for matchId 2235801354...
#   Getting match data for matchId 2235616678...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2235593538...
#   Getting match data for matchId 2235156906...
#   Getting match data for matchId 2235132097...
#   Getting match data for matchId 2235076328...
#   Getting match data for matchId 2234229020...
#   Getting match data for matchId 2234236813...
#   Getting match data for matchId 2234129674...
#   Getting match data for matchId 2234127585...
#   Getting match data for matchId 2234111638...
#   Getting match data for matchId 2234046264...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2234051148...
#   Getting match data for matchId 2233816715...
#   Getting match data for matchId 2232509107...
#   Getting match data for matchId 2231790561...
#   Getting match data for matchId 2231034725...
#   Getting match data for matchId 2231003915...
#   Getting match data for matchId 2231032013...
#   Getting match data for matchId 2230174267...
#   Getting match data for matchId 2229867120...
#   Getting match data for matchId 2229410105...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2229368773...
#   Getting match data for matchId 2229346917...
#   Getting match data for matchId 2220392474...
#   Getting match data for matchId 2208865361...
#   Getting match data for matchId 2208766761...
#   Getting match data for matchId 2208461564...
#   Getting match data for matchId 2208397669...
#   Getting match data for matchId 2207231425...
#   Getting match data for matchId 2207154267...
#   Getting match data for matchId 2205909996...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2205740643...
#   Getting match data for matchId 2204326147...
#   Getting match data for matchId 2204330201...
#   Getting match data for matchId 2204268002...
#   Getting match data for matchId 2204105171...
#   Getting match data for matchId 2203958138...
#   Getting match data for matchId 2203702727...
#   Getting match data for matchId 2203007922...
#   Getting match data for matchId 2202992314...
#   Getting match data for matchId 2202882901...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2201013948...
#   Getting match data for matchId 2200386458...
#   Getting match data for matchId 2200383102...
#   Getting match data for matchId 2200319231...
#   Getting match data for matchId 2200336946...
#   Getting match data for matchId 2199626192...
#   Getting match data for matchId 2199642463...
#   Getting match data for matchId 2199569592...
#   Getting match data for matchId 2199385003...
#   Getting match data for matchId 2199400624...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2199191540...
#   Getting match data for matchId 2199094887...
#   Getting match data for matchId 2198980737...
#   Getting match data for matchId 2198913662...
#   Getting match data for matchId 2198878585...
#   Getting match data for matchId 2198871857...
#   Getting match data for matchId 2197628863...
#   Getting match data for matchId 2197541342...
#   Getting match data for matchId 2197421463...
#   Getting match data for matchId 2192118477...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2192112149...
#   Getting match data for matchId 2192056296...
#   Getting match data for matchId 2191486803...
#   Getting match data for matchId 2191484187...
#   Getting match data for matchId 2191289986...
#   Getting match data for matchId 2191236145...
#   Getting match data for matchId 2191230944...
#   Getting match data for matchId 2191185252...
#   Getting match data for matchId 2191129112...
#   Getting match data for matchId 2190324621...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2190267787...
#   Getting match data for matchId 2190273877...
#   Getting match data for matchId 2190207531...
#   Getting match data for matchId 2189457205...
#   Getting match data for matchId 2188525330...
#   Getting match data for matchId 2188459438...
#   Getting match data for matchId 2188141823...
#   Getting match data for matchId 2188067400...
#   Getting match data for matchId 2188071060...
#   Getting match data for matchId 2187376478...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2187224124...
#   Getting match data for matchId 2186544903...
#   Getting match data for matchId 2186479721...
#   Getting match data for matchId 2185563349...
#   Getting match data for matchId 2185560368...
#   Getting match data for matchId 2185512982...
#   Getting match data for matchId 2185473174...
#   Getting match data for matchId 2184358905...
#   Getting match data for matchId 2184356383...
#   Getting match data for matchId 2184350695...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2182990625...
#   Getting match data for matchId 2175064354...
#   Getting match data for matchId 2175061129...
#   Getting match data for matchId 2174926639...
#   Getting match data for matchId 2174013673...
#   Getting match data for matchId 2174011751...
#   Getting match data for matchId 2173928196...
#   Getting match data for matchId 2173933192...
#   Getting match data for matchId 2173858474...
#   Getting match data for matchId 2173863144...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2172898446...
#   Getting match data for matchId 2172884901...
#   Getting match data for matchId 2172882489...
#   Getting match data for matchId 2172846462...
#   Getting match data for matchId 2172823056...
#   Getting match data for matchId 2172766565...
#   Getting match data for matchId 2172692190...
#   Getting match data for matchId 2172616724...
#   Getting match data for matchId 2172569012...
#   Getting match data for matchId 2172554418...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2172561078...
#   Getting match data for matchId 2172304294...
#   Getting match data for matchId 2171725311...
#   Getting match data for matchId 2171659390...
#   Getting match data for matchId 2171662837...
#   Getting match data for matchId 2171215191...
#   Getting match data for matchId 2171158347...
#   Getting match data for matchId 2171035936...
#   Getting match data for matchId 2171030026...
#   Getting match data for matchId 2170309540...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2170294483...
#   Getting match data for matchId 2170218991...
#   Getting match data for matchId 2169492411...
#   Getting match data for matchId 2169107095...
#   Getting match data for matchId 2167973049...
#   Getting match data for matchId 2167847718...
#   Getting match data for matchId 2167853595...
#   Getting match data for matchId 2167514513...
#   Getting match data for matchId 2167530545...
#   Getting match data for matchId 2167295626...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2167300437...
#   Getting match data for matchId 2167167186...
#   Getting match data for matchId 2166698346...
#   Getting match data for matchId 2166726665...
#   Getting match data for matchId 2166696270...
#   Getting match data for matchId 2166695494...
#   Getting match data for matchId 2166694075...
#   Getting match data for matchId 2166712811...
#   Getting match data for matchId 2166545383...
#   Getting match data for matchId 2166542566...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2166539999...
#   Getting match data for matchId 2165084576...
#   Getting match data for matchId 2165047170...
#   Getting match data for matchId 2164979535...
#   Getting match data for matchId 2164972283...
#   Getting match data for matchId 2164924865...
#   Getting match data for matchId 2164856689...
#   Getting match data for matchId 2164852297...
#   Getting match data for matchId 2164527950...
#   Getting match data for matchId 2164560504...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2164211080...
#   Getting match data for matchId 2164148685...
#   Getting match data for matchId 2164164850...
#   Getting match data for matchId 2164161353...
#   Getting match data for matchId 2164088125...
#   Getting match data for matchId 2164102704...
#   Getting match data for matchId 2164045007...
#   Getting match data for matchId 2164039854...
#   Getting match data for matchId 2163974306...
#   Getting match data for matchId 2163936183...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2163868711...
#   Getting match data for matchId 2163861483...
#   Getting match data for matchId 2163817142...
#   Getting match data for matchId 2163205118...
#   Getting match data for matchId 2163220430...
#   Getting match data for matchId 2163039103...
#   Getting match data for matchId 2162978835...
#   Getting match data for matchId 2162963387...
#   Getting match data for matchId 2162863111...
#   Getting match data for matchId 2162704906...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2162652153...
#   Getting match data for matchId 2162554228...
#   Getting match data for matchId 2162477988...
#   Getting match data for matchId 2162463946...
#   Getting match data for matchId 2162417518...
#   Getting match data for matchId 2162154916...
#   Getting match data for matchId 2162099600...
#   Getting match data for matchId 2162112731...
#   Getting match data for matchId 2162056249...
#   Getting match data for matchId 2162040359...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2161919574...
#   Getting match data for matchId 2161940994...
#   Getting match data for matchId 2161877348...
#   Getting match data for matchId 2161861711...
#   Getting match data for matchId 2161814135...
#   Getting match data for matchId 2161748741...
#   Getting match data for matchId 2161509956...
#   Getting match data for matchId 2161348979...
#   Getting match data for matchId 2161334585...
#   Getting match data for matchId 2161370510...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2161205848...
#   Getting match data for matchId 2161055522...
#   Getting match data for matchId 2161009229...
#   Getting match data for matchId 2161002937...
#   Getting match data for matchId 2160844155...
#   Getting match data for matchId 2160830459...
#   Getting match data for matchId 2160794442...
#   Getting match data for matchId 2160738878...
#   Getting match data for matchId 2160732361...
#   Getting match data for matchId 2160646851...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2160661532...
#   Getting match data for matchId 2160598389...
#   Getting match data for matchId 2160366283...
#   Getting match data for matchId 2160384144...
#   Getting match data for matchId 2159058535...
#   Getting match data for matchId 2159051183...
#   Getting match data for matchId 2159014151...
#   Getting match data for matchId 2158919067...
#   Getting match data for matchId 2157689926...
#   Getting match data for matchId 2157652329...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2157213058...
#   Getting match data for matchId 2157166271...
#   Getting match data for matchId 2157119308...
#   Getting match data for matchId 2157112442...
#   Getting match data for matchId 2157045519...
#   Getting match data for matchId 2156958915...
#   Getting match data for matchId 2156607758...
#   Getting match data for matchId 2156583565...
#   Getting match data for matchId 2156519494...
#   Getting match data for matchId 2156258705...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2156272347...
#   Getting match data for matchId 2156217018...
#   Getting match data for matchId 2156147722...
#   Getting match data for matchId 2156133635...
#   Getting match data for matchId 2155469224...
#   Getting match data for matchId 2155205776...
#   Getting match data for matchId 2154609187...
#   Getting match data for matchId 2154594417...
#   Getting match data for matchId 2154539721...
#   Getting match data for matchId 2154533109...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2154116364...
#   Getting match data for matchId 2154111361...
#   Getting match data for matchId 2153408388...
#   Getting match data for matchId 2153405124...
#   Getting match data for matchId 2153400532...
#   Getting match data for matchId 2153325735...
#   Getting match data for matchId 2153312825...
#   Getting match data for matchId 2153236010...
#   Getting match data for matchId 2153188296...
#   Getting match data for matchId 2153181545...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2153095810...
#   Getting match data for matchId 2153038707...
#   Getting match data for matchId 2152868078...
#   Getting match data for matchId 2152881727...
#   Getting match data for matchId 2152808157...
#   Getting match data for matchId 2152060014...
#   Getting match data for matchId 2151972265...
#   Getting match data for matchId 2149929048...
#   Getting match data for matchId 2147662750...
#   Getting match data for matchId 2147608023...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2147603975...
#   Getting match data for matchId 2147590691...
#   Getting match data for matchId 2147566175...
#   Getting match data for matchId 2147542944...
#   Getting match data for matchId 2147560237...
#   Getting match data for matchId 2147479011...
#   Getting match data for matchId 2147467462...
#   Getting match data for matchId 2147402757...
#   Getting match data for matchId 2147341167...
#   Getting match data for matchId 2147303937...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2147246826...
#   Getting match data for matchId 2147220776...
#   Getting match data for matchId 2147182042...
#   Getting match data for matchId 2147105038...
#   Getting match data for matchId 2147058576...
#   Getting match data for matchId 2147019499...
#   Getting match data for matchId 2147012039...
#   Getting match data for matchId 2146936279...
#   Getting match data for matchId 2146916339...
#   Getting match data for matchId 2146342242...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2146341303...
#   Getting match data for matchId 2146250956...
#   Getting match data for matchId 2146185397...
#   Getting match data for matchId 2146129387...
#   Getting match data for matchId 2146133287...
#   Getting match data for matchId 2146073917...
#   Getting match data for matchId 2146006840...
#   Getting match data for matchId 2145828187...
#   Getting match data for matchId 2145769617...
#   Getting match data for matchId 2145771361...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2145724285...
#   Getting match data for matchId 2145658745...
#   Getting match data for matchId 2145664218...
#   Getting match data for matchId 2145660464...
#   Getting match data for matchId 2145155242...
#   Getting match data for matchId 2145144455...
#   Getting match data for matchId 2145143025...
#   Getting match data for matchId 2145160868...
#   Getting match data for matchId 2145067695...
#   Getting match data for matchId 2144706592...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2144659119...
#   Getting match data for matchId 2144632747...
#   Getting match data for matchId 2143776734...
#   Getting match data for matchId 2143025601...
#   Getting match data for matchId 2142969103...
#   Getting match data for matchId 2142898746...
#   Getting match data for matchId 2142847319...
#   Getting match data for matchId 2142830402...
#   Getting match data for matchId 2142774698...
#   Getting match data for matchId 2142699258...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2142693044...
#   Getting match data for matchId 2142556300...
#   Getting match data for matchId 2141107515...
#   Getting match data for matchId 2140941167...
#   Getting match data for matchId 2140883939...
#   Getting match data for matchId 2140825380...
#   Getting match data for matchId 2140749042...
#   Getting match data for matchId 2140708434...
#   Getting match data for matchId 2139314174...
#   Getting match data for matchId 2139246696...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2138980029...
#   Getting match data for matchId 2138936353...
#   Getting match data for matchId 2138922350...
#   Getting match data for matchId 2138875369...
#   Getting match data for matchId 2138829155...
#   Getting match data for matchId 2138812781...
#   Getting match data for matchId 2137755215...
#   Getting match data for matchId 2137744785...
#   Getting match data for matchId 2137762609...
#   Getting match data for matchId 2137751628...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2136377563...
#   Getting match data for matchId 2136380504...
#   Getting match data for matchId 2136192767...
#   Getting match data for matchId 2136140221...
#   Getting match data for matchId 2136064478...
#   Getting match data for matchId 2136016415...
#   Getting match data for matchId 2135999914...
#   Getting match data for matchId 2135913047...
#   Getting match data for matchId 2135221591...
#   Getting match data for matchId 2135156015...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2135105220...
#   Getting match data for matchId 2134982722...
#   Getting match data for matchId 2134945177...
#   Getting match data for matchId 2134905078...
#   Getting match data for matchId 2133644559...
#   Getting match data for matchId 2133602541...
#   Getting match data for matchId 2133535228...
#   Getting match data for matchId 2133459299...
#   Getting match data for matchId 2133416158...
#   Getting match data for matchId 2133399762...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2133351700...
#   Getting match data for matchId 2132810681...
#   Getting match data for matchId 2131618872...
#   Getting match data for matchId 2131559046...
#   Getting match data for matchId 2131543348...
#   Getting match data for matchId 2131505267...
#   Getting match data for matchId 2131445798...
#   Getting match data for matchId 2130704905...
#   Getting match data for matchId 2130710988...
#   Getting match data for matchId 2130655182...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2130558392...
#   Getting match data for matchId 2130572049...
#   Getting match data for matchId 2130498713...
#   Getting match data for matchId 2130490489...
#   Getting match data for matchId 2130102968...
#   Getting match data for matchId 2129789748...
#   Getting match data for matchId 2129706894...
#   Getting match data for matchId 2129694023...
#   Getting match data for matchId 2129569648...
#   Getting match data for matchId 2129546214...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2128514189...
#   Getting match data for matchId 2127466755...
#   Getting match data for matchId 2127471043...
#   Getting match data for matchId 2127396658...
#   Getting match data for matchId 2126325775...
#   Getting match data for matchId 2126267261...
#   Getting match data for matchId 2125485300...
#   Getting match data for matchId 2123871747...
#   Getting match data for matchId 2122870787...
#   Getting match data for matchId 2122823535...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2122751280...
#   Getting match data for matchId 2122322261...
#   Getting match data for matchId 2122290544...
#   Getting match data for matchId 2122227090...
#   Getting match data for matchId 2122242279...
#   Getting match data for matchId 2118318060...
#   Getting match data for matchId 2118258189...
#   Getting match data for matchId 2118198019...
#   Getting match data for matchId 2118210772...
#   Getting match data for matchId 2118088986...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2117792602...
#   Getting match data for matchId 2117800565...
#   Getting match data for matchId 2116795425...
#   Getting match data for matchId 2116738344...
#   Getting match data for matchId 2116599627...
#   Getting match data for matchId 2116598144...
#   Getting match data for matchId 2116586534...
#   Getting match data for matchId 2116584240...
#   Getting match data for matchId 2116069602...
#   Getting match data for matchId 2116051822...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2115893565...
#   Getting match data for matchId 2115697441...
#   Getting match data for matchId 2115710837...
#   Getting match data for matchId 2115574618...
#   Getting match data for matchId 2115256421...
#   Getting match data for matchId 2115189348...
#   Getting match data for matchId 2115192542...
#   Getting match data for matchId 2115134316...
#   Getting match data for matchId 2115082849...
#   Getting match data for matchId 2114905639...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2114164301...
#   Getting match data for matchId 2114030574...
#   Getting match data for matchId 2113963928...
#   Getting match data for matchId 2113895139...
#   Getting match data for matchId 2113836112...
#   Getting match data for matchId 2113799165...
#   Getting match data for matchId 2113748603...
#   Getting match data for matchId 2113283792...
#   Getting match data for matchId 2113216767...
#   Getting match data for matchId 2113078460...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2113089869...
#   Getting match data for matchId 2112809318...
#   Getting match data for matchId 2112805543...
#   Getting match data for matchId 2112737857...
#   Getting match data for matchId 2112722227...
#   Getting match data for matchId 2112666250...
#   Getting match data for matchId 2112535010...
#   Getting match data for matchId 2112533789...
#   Getting match data for matchId 2112348834...
#   Getting match data for matchId 2112357224...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2112354709...
#   Getting match data for matchId 2112351649...
#   Getting match data for matchId 2112277431...
#   Getting match data for matchId 2112283299...
#   Getting match data for matchId 2112219155...
#   Getting match data for matchId 2112212806...
#   Getting match data for matchId 2112149044...
#   Getting match data for matchId 2112133997...
#   Getting match data for matchId 2111322542...
#   Getting match data for matchId 2111238247...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2111244379...
#   Getting match data for matchId 2111230241...
#   Getting match data for matchId 2110834177...
#   Getting match data for matchId 2110768453...
#   Getting match data for matchId 2110784289...
#   Getting match data for matchId 2110428526...
#   Getting match data for matchId 2110424939...
#   Getting match data for matchId 2109107053...
#   Getting match data for matchId 2109026038...
#   Getting match data for matchId 2109011823...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2107006593...
#   Getting match data for matchId 2107013615...
#   Getting match data for matchId 2106959561...
#   Getting match data for matchId 2106702461...
#   Getting match data for matchId 2106629414...
#   Getting match data for matchId 2106645853...
#   Getting match data for matchId 2106631714...
#   Getting match data for matchId 2106509005...
#   Getting match data for matchId 2106506600...
#   Getting match data for matchId 2106484230...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2105624929...
#   Getting match data for matchId 2105624392...
#   Getting match data for matchId 2105633859...
#   Getting match data for matchId 2105613281...
#   Getting match data for matchId 2105622844...
#   Getting match data for matchId 2104654503...
#   Getting match data for matchId 2104640345...
#   Getting match data for matchId 2104426630...
#   Getting match data for matchId 2104402539...
#   Getting match data for matchId 2104356904...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2104340568...
#   Getting match data for matchId 2104275615...
#   Getting match data for matchId 2104270469...
#   Getting match data for matchId 2103576918...
#   Getting match data for matchId 2103590064...
#   Getting match data for matchId 2103505318...
#   Getting match data for matchId 2103438087...
#   Getting match data for matchId 2103444293...
#   Getting match data for matchId 2103429922...
#   Getting match data for matchId 2102701653...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2102690367...
#   Getting match data for matchId 2102598182...
#   Getting match data for matchId 2102584482...
#   Getting match data for matchId 2102286345...
#   Getting match data for matchId 2102270484...
#   Getting match data for matchId 2102206843...
#   Getting match data for matchId 2102204168...
#   Getting match data for matchId 2101289470...
#   Getting match data for matchId 2101305414...
#   Getting match data for matchId 2101282751...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2101131616...
#   Getting match data for matchId 2101140747...
#   Getting match data for matchId 2101139793...
#   Getting match data for matchId 2101049215...
#   Getting match data for matchId 2101037875...
#   Getting match data for matchId 2101047414...
#   Getting match data for matchId 2099850758...
#   Getting match data for matchId 2099756897...
#   Getting match data for matchId 2099754889...
#   Getting match data for matchId 2099772078...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2099709368...
#   Getting match data for matchId 2099706276...
#   Getting match data for matchId 2099693013...
#   Getting match data for matchId 2099700224...
#   Getting match data for matchId 2099015259...
#   Getting match data for matchId 2099022342...
#   Getting match data for matchId 2098659613...
#   Getting match data for matchId 2098675402...
#   Getting match data for matchId 2097740258...
#   Getting match data for matchId 2097676776...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2097672303...
#   Getting match data for matchId 2097670013...
#   Getting match data for matchId 2096693401...
#   Getting match data for matchId 2095398383...
#   Getting match data for matchId 2095292100...
#   Getting match data for matchId 2095217271...
#   Getting match data for matchId 2095223440...
#   Getting match data for matchId 2093118576...
#   Getting match data for matchId 2093113882...
#   Getting match data for matchId 2092742062...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2092676821...
#   Getting match data for matchId 2092653074...
#   Getting match data for matchId 2091933468...
#   Getting match data for matchId 2091910186...
#   Getting match data for matchId 2091753626...
#   Getting match data for matchId 2091759974...
#   Getting match data for matchId 2091706259...
#   Getting match data for matchId 2091692379...
#   Getting match data for matchId 2091690299...
#   Getting match data for matchId 2091606668...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2091603033...
#   Getting match data for matchId 2091609778...
#   Getting match data for matchId 2089661495...
#   Getting match data for matchId 2089548758...
#   Getting match data for matchId 2088834501...
#   Getting match data for matchId 2088840967...
#   Getting match data for matchId 2088766480...
#   Getting match data for matchId 2088771903...
#   Getting match data for matchId 2088687246...
#   Getting match data for matchId 2088672543...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2088628872...
#   Getting match data for matchId 2087952748...
#   Getting match data for matchId 2087868178...
#   Getting match data for matchId 2087871835...
#   Getting match data for matchId 2087817053...
#   Getting match data for matchId 2087481348...
#   Getting match data for matchId 2087268565...
#   Getting match data for matchId 2087266073...
#   Getting match data for matchId 2087263069...
#   Getting match data for matchId 2087079454...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2087065973...
#   Getting match data for matchId 2084841472...
#   Getting match data for matchId 2083994563...
#   Getting match data for matchId 2084000220...
#   Getting match data for matchId 2083920704...
#   Getting match data for matchId 2083875184...
#   Getting match data for matchId 2083880040...
#   Getting match data for matchId 2083796991...
#   Getting match data for matchId 2083802888...
#   Getting match data for matchId 2083800768...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2083003237...
#   Getting match data for matchId 2082938332...
#   Getting match data for matchId 2082933213...
#   Getting match data for matchId 2082888551...
#   Getting match data for matchId 2082895229...
#   Getting match data for matchId 2082796397...
#   Getting match data for matchId 2082792784...
#   Getting match data for matchId 2082728933...
#   Getting match data for matchId 2082156355...
#   Getting match data for matchId 2082172047...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2082094716...
#   Getting match data for matchId 2082028396...
#   Getting match data for matchId 2082003357...
#   Getting match data for matchId 2081887642...
#   Getting match data for matchId 2081882345...
#   Getting match data for matchId 2081126840...
#   Getting match data for matchId 2081101370...
#   Getting match data for matchId 2080385246...
#   Getting match data for matchId 2080319416...
#   Getting match data for matchId 2080231739...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2080158007...
#   Getting match data for matchId 2080153043...
#   Getting match data for matchId 2080088472...
#   Getting match data for matchId 2080103833...
#   Getting match data for matchId 2080018412...
#   Getting match data for matchId 2079467780...
#   Getting match data for matchId 2079387243...
#   Getting match data for matchId 2077421691...
#   Getting match data for matchId 2077063300...
#   Getting match data for matchId 2076618570...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2076604101...
#   Getting match data for matchId 2076554149...
#   Getting match data for matchId 2076523334...
#   Getting match data for matchId 2076487853...
#   Getting match data for matchId 2074927515...
#   Getting match data for matchId 2074932443...
#   Getting match data for matchId 2074910488...
#   Getting match data for matchId 2074894987...
# SAVING 401.0 MATCHES!
#   Approximate number of successfully pulled matches: 405.0
#   Average time per (successful) match request: 1.9505445107
# Number of successfully pulled summoners: 1.0
# Average time per (successfully pulled) summoner: 782.168375015
# Getting match history from summoner: 29238121
# An ERROR occurred when pulling match history data for summonerId 29238121! Too many requests
# Getting match history from summoner: 24478122
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
# An ERROR occurred when pulling match history data for summonerId 24478122! Too many requests
# Getting match history from summoner: 23551158
# An ERROR occurred when pulling match history data for summonerId 23551158! Too many requests
# Getting match history from summoner: 20166831
# An ERROR occurred when pulling match history data for summonerId 20166831! Too many requests
# Getting match history from summoner: 38679261
# An ERROR occurred when pulling match history data for summonerId 38679261! Too many requests
# Getting match history from summoner: 29771089
# An ERROR occurred when pulling match history data for summonerId 29771089! Too many requests
# Getting match history from summoner: 48676609
# An ERROR occurred when pulling match history data for summonerId 48676609! Too many requests
# Getting match history from summoner: 22053490
#   Getting match data for matchId 2294211567...
#   Getting match data for matchId 2292988218...
#   Getting match data for matchId 2292970396...
#   Getting match data for matchId 2291766226...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2291719288...
#   Getting match data for matchId 2291658254...
#   Getting match data for matchId 2291644699...
#   Getting match data for matchId 2291608227...
#   Getting match data for matchId 2291587090...
#   Getting match data for matchId 2291600105...
#   Getting match data for matchId 2291526740...
#   Getting match data for matchId 2291523198...
#   Getting match data for matchId 2290961899...
#   Getting match data for matchId 2289860179...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2289318921...
#   Getting match data for matchId 2289256766...
#   Getting match data for matchId 2289199151...
#   Getting match data for matchId 2288795448...
#   Getting match data for matchId 2288110161...
#   Getting match data for matchId 2287423620...
#   Getting match data for matchId 2287368701...
#   Getting match data for matchId 2287364844...
#   Getting match data for matchId 2287341714...
#   Getting match data for matchId 2278984139...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2278971766...
#   Getting match data for matchId 2278797807...
#   Getting match data for matchId 2278454279...
#   Getting match data for matchId 2278396686...
#   Getting match data for matchId 2278347812...
#   Getting match data for matchId 2278342966...
#   Getting match data for matchId 2278276646...
#   Getting match data for matchId 2278144062...
#   Getting match data for matchId 2277460749...
#   Getting match data for matchId 2277398245...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2277391202...
#   Getting match data for matchId 2265114192...
#   Getting match data for matchId 2265101394...
#   Getting match data for matchId 2257567188...
#   Getting match data for matchId 2229806815...
#   Getting match data for matchId 2211268260...
#   Getting match data for matchId 2208752772...
#   Getting match data for matchId 2207476231...
#   Getting match data for matchId 2207483810...
#   Getting match data for matchId 2207473115...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2207092749...
#   Getting match data for matchId 2206537944...
#   Getting match data for matchId 2205927572...
#   Getting match data for matchId 2205913626...
#   Getting match data for matchId 2191295848...
#   Getting match data for matchId 2165744940...
#   Getting match data for matchId 2165741114...
#   Getting match data for matchId 2141518164...
#   Getting match data for matchId 2119280172...
#   Getting match data for matchId 2119243447...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2119187009...
#   Getting match data for matchId 2119170364...
#   Getting match data for matchId 2119045206...
#   Getting match data for matchId 2118480434...
#   Getting match data for matchId 2118446178...
#   Getting match data for matchId 2118386407...
#   Getting match data for matchId 2118326754...
#   Getting match data for matchId 2117759664...
#   Getting match data for matchId 2117741535...
#   Getting match data for matchId 2117678410...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2117682931...
#   Getting match data for matchId 2117092833...
#   Getting match data for matchId 2116547291...
#   Getting match data for matchId 2116524463...
#   Getting match data for matchId 2116476501...
#   Getting match data for matchId 2116354264...
#   Getting match data for matchId 2116317876...
#   Getting match data for matchId 2116258237...
#   Getting match data for matchId 2116044329...
#   Getting match data for matchId 2115895719...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2115706629...
#   Getting match data for matchId 2115701502...
#   Getting match data for matchId 2115623944...
#   Getting match data for matchId 2115576922...
#   Getting match data for matchId 2115198053...
#   Getting match data for matchId 2115139624...
#   Getting match data for matchId 2114745411...
#   Getting match data for matchId 2114730411...
#   Getting match data for matchId 2114654588...
#   Getting match data for matchId 2114432048...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2114149406...
#   Getting match data for matchId 2114146700...
#   Getting match data for matchId 2114141631...
#   Getting match data for matchId 2114084464...
#   Getting match data for matchId 2114039419...
#   Getting match data for matchId 2114012683...
#   Getting match data for matchId 2113956930...
#   Getting match data for matchId 2113830743...
#   Getting match data for matchId 2113792155...
#   Getting match data for matchId 2113406651...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2113382341...
#   Getting match data for matchId 2113325287...
#   Getting match data for matchId 2113279718...
#   Getting match data for matchId 2113078358...
#   Getting match data for matchId 2113070350...
#   Getting match data for matchId 2112851094...
#   Getting match data for matchId 2112804405...
#   Getting match data for matchId 2112738987...
#   Getting match data for matchId 2112733259...
#   Getting match data for matchId 2112677913...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2112652959...
#   Getting match data for matchId 2112609100...
#   Getting match data for matchId 2112596901...
#   Getting match data for matchId 2112592908...
#   Getting match data for matchId 2112528590...
#   Getting match data for matchId 2112289687...
#   Getting match data for matchId 2112273248...
#   Getting match data for matchId 2112208649...
#   Getting match data for matchId 2112119956...
#   Getting match data for matchId 2112045752...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2112052254...
#   Getting match data for matchId 2111999170...
#   Getting match data for matchId 2111986762...
#   Getting match data for matchId 2111550610...
#   Getting match data for matchId 2111457415...
#   Getting match data for matchId 2111453170...
#   Getting match data for matchId 2111398456...
#   Getting match data for matchId 2111164654...
#   Getting match data for matchId 2111171346...
#   Getting match data for matchId 2111098350...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2111095964...
# ...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2139421662...
#   Getting match data for matchId 2139362029...
#   Getting match data for matchId 2139314906...
#   Getting match data for matchId 2137201302...
#   Getting match data for matchId 2136505695...
#   Getting match data for matchId 2136382930...
#   Getting match data for matchId 2133030074...
#   Getting match data for matchId 2132978459...
#   Getting match data for matchId 2132995997...
#   Getting match data for matchId 2130816121...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2130103409...
#   Getting match data for matchId 2130080084...
#   Getting match data for matchId 2129860251...
#   Getting match data for matchId 2129807974...
#   Getting match data for matchId 2128625283...
#   Getting match data for matchId 2128613342...
#   Getting match data for matchId 2128578747...
#   Getting match data for matchId 2128564908...
#   Getting match data for matchId 2126999669...
#   Getting match data for matchId 2126995173...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2121446369...
#   Getting match data for matchId 2121442474...
#   Getting match data for matchId 2121321287...
#   Getting match data for matchId 2120771059...
#   Getting match data for matchId 2120520366...
#   Getting match data for matchId 2120486704...
#   Getting match data for matchId 2120045800...
#   Getting match data for matchId 2120039862...
#   Getting match data for matchId 2119366432...
#   Getting match data for matchId 2119289339...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2118757966...
#   Getting match data for matchId 2118440635...
#   Getting match data for matchId 2118380398...
#   Getting match data for matchId 2118268536...
#   Getting match data for matchId 2115240450...
#   Getting match data for matchId 2115183458...
#   Getting match data for matchId 2115145934...
#   Getting match data for matchId 2115087090...
#   Getting match data for matchId 2114096110...
#   Getting match data for matchId 2114022561...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2113646921...
#   Getting match data for matchId 2113563238...
#   Getting match data for matchId 2113286575...
#   Getting match data for matchId 2113270779...
#   Getting match data for matchId 2112215465...
#   Getting match data for matchId 2112061578...
#   Getting match data for matchId 2111998689...
#   Getting match data for matchId 2111975835...
#   Getting match data for matchId 2111972954...
#   Getting match data for matchId 2111981040...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2111657663...
#   Getting match data for matchId 2111656386...
#   Getting match data for matchId 2111409490...
#   Getting match data for matchId 2111381352...
#   Getting match data for matchId 2111165512...
#   Getting match data for matchId 2111172733...
#   Getting match data for matchId 2110767703...
#   Getting match data for matchId 2110773304...
#   Getting match data for matchId 2110181872...
#   Getting match data for matchId 2110098054...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2108936733...
#   Getting match data for matchId 2107678197...
#   Getting match data for matchId 2107663226...
#   Getting match data for matchId 2107598673...
#   Getting match data for matchId 2107604075...
#   Getting match data for matchId 2107590588...
#   Getting match data for matchId 2107507146...
#   Getting match data for matchId 2107524185...
#   Getting match data for matchId 2107511730...
#   Getting match data for matchId 2106930443...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2106797976...
#   Getting match data for matchId 2106792605...
#   Getting match data for matchId 2106708453...
#   Getting match data for matchId 2106714344...
#   Getting match data for matchId 2106493265...
#   Getting match data for matchId 2105840184...
#   Getting match data for matchId 2105776272...
#   Getting match data for matchId 2105155235...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2105160628...
#   Getting match data for matchId 2104986668...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2104973172...
#   Getting match data for matchId 2104879474...
#   Getting match data for matchId 2104875509...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2104882531...
#   Getting match data for matchId 2104813421...
#   Getting match data for matchId 2104810991...
#   Getting match data for matchId 2104727197...
#   Getting match data for matchId 2104746503...
#   Getting match data for matchId 2104416446...
#   Getting match data for matchId 2104412119...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2103758751...
#   Getting match data for matchId 2103216314...
#   Getting match data for matchId 2103202763...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2101917278...
#   Getting match data for matchId 2101125829...
#   Getting match data for matchId 2101049692...
#   Getting match data for matchId 2101059020...
#   Getting match data for matchId 2101048390...
#   Getting match data for matchId 2100311233...
#   Getting match data for matchId 2100238788...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2100237226...
#   Getting match data for matchId 2100139598...
#   Getting match data for matchId 2100148941...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2099380789...
#   Getting match data for matchId 2099249577...
#   Getting match data for matchId 2099248408...
#   Getting match data for matchId 2099257432...
#   Getting match data for matchId 2099256739...
#   Getting match data for matchId 2099174820...
#   Getting match data for matchId 2098449678...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2098433329...
#   Getting match data for matchId 2097428222...
#   Getting match data for matchId 2097436815...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2097433432...
#   Getting match data for matchId 2097430992...
#   Getting match data for matchId 2097326890...
#   Getting match data for matchId 2097343754...
#   Getting match data for matchId 2097019721...
#   Getting match data for matchId 2097014771...
#   Getting match data for matchId 2095939628...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2095945228...
#   Getting match data for matchId 2095951350...
#   Getting match data for matchId 2095866486...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2095862960...
#   Getting match data for matchId 2095849888...
#   Getting match data for matchId 2095448886...
#   Getting match data for matchId 2095458289...
#   Getting match data for matchId 2095457528...
#   Getting match data for matchId 2095466391...
#   Getting match data for matchId 2094786141...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2094782045...
#   Getting match data for matchId 2094729216...
#   Getting match data for matchId 2094266880...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2094140400...
#   Getting match data for matchId 2092877478...
#   Getting match data for matchId 2092896780...
#   Getting match data for matchId 2092164216...
#   Getting match data for matchId 2091912532...
#   Getting match data for matchId 2091033419...
#   Getting match data for matchId 2090939051...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2090955545...
#   Getting match data for matchId 2090950905...
#   Getting match data for matchId 2090876644...
#   Getting match data for matchId 2090640539...
#   Getting match data for matchId 2090587126...
#   Getting match data for matchId 2090583664...
#   Getting match data for matchId 2090498364...
#   Getting match data for matchId 2089899061...
#   Getting match data for matchId 2089895863...
#   Getting match data for matchId 2089142826...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2089160859...
#   Getting match data for matchId 2088283902...
#   Getting match data for matchId 2086449369...
#   Getting match data for matchId 2086467393...
#   Getting match data for matchId 2084284403...
#   Getting match data for matchId 2084260262...
#   Getting match data for matchId 2084204843...
#   Getting match data for matchId 2083872743...
#   Getting match data for matchId 2083798790...
#   Getting match data for matchId 2083732737...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2083671491...
#   Getting match data for matchId 2083444915...
#   Getting match data for matchId 2083412790...
#   Getting match data for matchId 2078042803...
#   Getting match data for matchId 2078002831...
#   Getting match data for matchId 2077963012...
#   Getting match data for matchId 2075124926...
#   Getting match data for matchId 2075113011...
#   Getting match data for matchId 2075077264...
#   Getting match data for matchId 2075047769...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2074354106...
#   Getting match data for matchId 2074274903...
#   Getting match data for matchId 2074225780...
#   Getting match data for matchId 2074148385...
#   Getting match data for matchId 2074192030...
#   Getting match data for matchId 2074049113...
#   Getting match data for matchId 2073681866...
#   Getting match data for matchId 2073627381...
#   Getting match data for matchId 2073354527...
#   Getting match data for matchId 2073275595...
#     Sleeping for 5 seconds to wait for request timelimit...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2073261597...
#   Getting match data for matchId 2073218468...
#   Getting match data for matchId 2073205236...
#   Getting match data for matchId 2073213093...
#   Getting match data for matchId 2073210036...
# SAVING 385 MATCHES!
#   Approximate number of successfully pulled matches: 5229.0
#   Average time per (successful) match request: 2.02764601034
# Number of successfully pulled summoners: 31.0
# Average time per (successfully pulled) summoner: 340.70993848
# Getting match history from summoner: 31773474
#   Getting match data for matchId 2288568305...
#   Getting match data for matchId 2287376690...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2287371946...
#   Getting match data for matchId 2287317524...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2285527349...
#   Getting match data for matchId 2285521317...
#   Getting match data for matchId 2285520645...
#   Getting match data for matchId 2284503123...
#   Getting match data for matchId 2283567131...
#   Getting match data for matchId 2283491452...
#   Getting match data for matchId 2282820858...
#   Getting match data for matchId 2282054133...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2282061577...
#   Getting match data for matchId 2281927327...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2281916197...
#   Getting match data for matchId 2281935253...
#   Getting match data for matchId 2281914906...
#   Getting match data for matchId 2281680105...
#   Getting match data for matchId 2281011668...
#   Getting match data for matchId 2272416386...
#   Getting match data for matchId 2261442030...
#   Getting match data for matchId 2254542127...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2254550708...
#   Getting match data for matchId 2252812588...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2244754824...
#   Getting match data for matchId 2238553484...
#   Getting match data for matchId 2238542656...
#   Getting match data for matchId 2236985685...
#   Getting match data for matchId 2236963451...
#   Getting match data for matchId 2236906313...
#   Getting match data for matchId 2236915576...
#   Getting match data for matchId 2236894971...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2235292392...
#   Getting match data for matchId 2235270981...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2235204173...
#   Getting match data for matchId 2228781386...
#   Getting match data for matchId 2227502654...
#   Getting match data for matchId 2227500207...
#   Getting match data for matchId 2227458382...
#   Getting match data for matchId 2227436499...
#   Getting match data for matchId 2227455461...
#   Getting match data for matchId 2227434983...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2227440101...
#   Getting match data for matchId 2227367607...
#     Sleeping for 5 seconds to wait for request timelimit...
#   Getting match data for matchId 2226714910...
#     503 ERROR! Retrying base_request:  v2.2/match/2226714910  0.01% failed
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-7debe9801448> in <module>()
#     261
#     262 if __name__ == '__main__':
# --> 263     main()
#
# <ipython-input-1-7debe9801448> in main()
#     195                 print("  Getting match data for matchId {0}...".format(match['matchId']))
#     196                 try:
# --> 197                     match_data = w.get_match(match['matchId'],include_timeline=False)
#     198                 except LoLException:
#     199                     pulled_matchIds.append(match['matchId'])
#
# //anaconda/lib/python2.7/site-packages/riotwatcher/riotwatcher.pyc in get_match(self, match_id, region, include_timeline)
#     532             '{match_id}'.format(match_id=match_id),
#     533             region,
# --> 534             includeTimeline=include_timeline
#     535         )
#     536
#
# //anaconda/lib/python2.7/site-packages/riotwatcher/riotwatcher.pyc in _match_request(self, end_url, region, **kwargs)
#     525             ),
#     526             region,
# --> 527             **kwargs
#     528         )
#     529
#
# //anaconda/lib/python2.7/site-packages/riotwatcher/riotwatcher.pyc in base_request(self, url, region, static, **kwargs)
#     262             time.sleep(5)
#     263             r = self.base_request_retry(url,region,static, **kwargs)
# --> 264         raise_status(r)
#     265         return r.json()
#     266
#
# //anaconda/lib/python2.7/site-packages/riotwatcher/riotwatcher.pyc in raise_status(response)
#     172
#     173 def raise_status(response):
# --> 174     if response.status_code == 400:
#     175         raise error_400
#     176     elif response.status_code == 401:
#
# AttributeError: 'NoneType' object has no attribute 'status_code'
